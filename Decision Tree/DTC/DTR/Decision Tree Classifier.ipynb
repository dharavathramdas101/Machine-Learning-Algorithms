# %% [markdown]
# # Machine Learning :

# %% [markdown]
# ## Decision Tree Classifier:

# %% [markdown]
# ## Decision Tree Classifier Practical implementation on Wine Quality Dataset

# %% [markdown]
# ## Life Cycle of Machine Learning Project:
#     1.Undestanding the Problem Statement
#     2.Data Collection
#     3.EDA
#     4.Data Cleaning
#     5.Data Preprocessing
#     6.Model Training
#     7.Chose best model

# %% [markdown]
# ## 1.Problem Statement
#     Predict wine quality using Decision Tree Classifier

# %% [markdown]
# ## 2.Data Collection

# %%
Dataset Link: "https://raw.githubusercontent.com/shrikant-temburwar/Wine-Quality-Dataset/master/winequality-red.csv"
Code Link: https://github.com/dharavathramdas101/Machine-learning-Algorithms-Practical-implementation

# %% [markdown]
# ## Importing data required packages

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Importing dataset

# %%
df=pd.read_csv("https://raw.githubusercontent.com/shrikant-temburwar/Wine-Quality-Dataset/master/winequality-red.csv",sep = ';')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 5            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 5                 13.0                  40.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
df['quality'].nunique()
# Out:
# 6

# %%
df['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
df.describe().T
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# ...

# %% [markdown]
# ## 3.Data Cleaning

# %%
df.duplicated().sum()
# Out:
# 240

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Example

# %%
demo = pd.DataFrame([1,3,4,6,5,4,2,3,4,6,7,4,3])

# %%
demo.duplicated().sum()
# Out:
# 6

# %% [markdown]
# ## Independent and Dependent Seperation

# %%
X =df.drop("quality",axis=1)

# %%
y=df['quality']

# %% [markdown]
# ## train test split

# %%
from sklearn.model_selection import train_test_split,GridSearchCV

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.33,random_state=10)

# %% [markdown]
# ## Model

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.score(X_train,y_train)
# Out:
# 1.0

# %% [markdown]
# ## Predicting

# %%
y_predict = model.predict(X_test)
y_predict
# Out:
# array([6, 6, 6, 5, 6, 7, 6, 7, 5, 7, 5, 5, 6, 5, 5, 6, 5, 5, 7, 5, 6, 6,
#        6, 5, 5, 5, 6, 6, 5, 5, 6, 6, 6, 5, 6, 5, 5, 4, 7, 4, 5, 6, 6, 6,
#        5, 5, 5, 5, 5, 6, 6, 5, 5, 6, 5, 7, 6, 7, 5, 5, 6, 6, 7, 5, 6, 6,
#        5, 6, 6, 5, 5, 5, 5, 6, 4, 5, 6, 5, 5, 6, 6, 5, 5, 5, 5, 5, 6, 7,
#        5, 5, 5, 5, 5, 6, 6, 5, 5, 6, 5, 6, 6, 5, 6, 5, 5, 5, 6, 7, 5, 5,
#        5, 5, 7, 5, 5, 6, 7, 6, 5, 6, 4, 6, 5, 6, 7, 6, 7, 5, 5, 5, 6, 5,
#        5, 5, 4, 5, 5, 6, 4, 7, 5, 5, 7, 6, 5, 5, 5, 6, 5, 7, 6, 6, 6, 5,
#        5, 6, 6, 5, 6, 6, 5, 6, 5, 5, 5, 5, 6, 5, 5, 6, 7, 6, 6, 5, 5, 7,
#        6, 6, 6, 5, 6, 6, 6, 5, 7, 5, 5, 6, 5, 5, 7, 6, 6, 5, 5, 5, 6, 5,
#        7, 7, 6, 5, 5, 6, 6, 5, 6, 4, 6, 6, 6, 5, 7, 7, 6, 5, 5, 5, 7, 8,
#        4, 6, 5, 5, 6, 6, 6, 6, 5, 6, 5, 5, 5, 7, 6, 5, 5, 5, 5, 4, 5, 5,
#        4, 6, 8, 8, 5, 6, 6, 5, 6, 4, 8, 6, 6, 6, 7, 5, 6, 8, 6, 7, 5, 6,
#        6, 6, 5, 6, 5, 6, 6, 6, 7, 5, 6, 6, 7, 7, 7, 6, 7, 5, 5, 6, 5, 6,
# ...

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_predict)
# Out:
# 0.5144766146993318

# %% [markdown]
# ## GridSearchCV

# %%
grid_param = {
    'criterion':['gini','entropy'],
    'max_depth' : range(2,32,1),
    'min_samples_leaf' : range(1,10,1),
    'min_samples_split': range(2,10,1),
    'splitter' : ['best','random']
}

# %%
from sklearn.model_selection import GridSearchCV
grid_search = GridSearchCV(estimator=model,param_grid=grid_param,cv=5)

# %%
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(2, 32),
#                          'min_samples_leaf': range(1, 10),
#                          'min_samples_split': range(2, 10),
#                          'splitter': ['best', 'random']})

# %%
grid_search.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 13,
#  'min_samples_leaf': 9,
#  'min_samples_split': 5,
#  'splitter': 'random'}

# %%
model_with_best_params = DecisionTreeClassifier(criterion= 'gini',
 max_depth= 13,
 min_samples_leaf= 9,
 min_samples_split= 5,
 splitter= 'random')

# %%
model_with_best_params.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=13, min_samples_leaf=9, min_samples_split=5,
#                        splitter='random')

# %%
y_predict2 = model_with_best_params.predict(X_test)

# %%
accuracy_score(y_test,y_predict2)
# Out:
# 0.5657015590200446
